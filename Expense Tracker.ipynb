# %%
#### expense Tracker Project

expensesList= []      #List of all expenses in the form of dictionary
print("Welcome to the Expense Tracker")

while True:
    print("===Menu===")
    print("1. Add expense")
    print("2. Veiw all expenses")
    print("3. View Total Khrcha")
    print("4. Exit")

    choice= int(input("Please enter your choice:"))

#Add Expense
    if(choice == 1):
        date= input("Kiss date pe kharcha kiya tha")
        category= input("kiss type ka kharcha kiya tha? (Food, Travel, Makeup, Party, Book and etc)")
        description= input("Write some description.")
        amount= float(input("Enter the amount: "))

        expense= {
            "date": date,
            "category": category,
            "description": description,
            "amount": amount
        }

        expensesList.append(expense)
        print(" \n done Bro. Expense is added succesfully")


#View All expenses
    elif(choice==2):
        if( len(expenseList)==0):
            print("No expense added. Jao Phle klharcha kro.")
        else:
            print("===Ye rha aapka sara expense===")
            count=1
            for eachExpense in expesesList:
                print(f"Kharcha Number {Count} -> {eachExpense["date"]}, {eachExpense["category"]}, {eachExpense["description"]}, {eachExpense["amount"]} ")
                count= count+1



#Viw total Spending
    elif(choice==3):
        total=0
        for eachExpense in expensesList:
            total= total+ eachExpense["amount"]

        print(" \n Total Kharcha: ", total)


#exit
    elif(choice==4):
        print("Thankyou for using our system")
        break

    else:
        print("Invalid Entry. Try Again")
# Out:
# Welcome to the Expense Tracker
# ===Menu===
# 1. Add expense
# 2. Veiw all expenses
# 3. View Total Khrcha
# 4. Exit
